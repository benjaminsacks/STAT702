# %%
#Problem 8a
import pandas as pd
college=pd.read_csv('College.csv')

# %%
#8b
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv('College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0': 'College'},
axis=1)
college3 = college3.set_index('College')

# %%
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college = college3

# %%
#8c
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
#8d
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']]);

# %%
#8e
college.boxplot('Outstate', by='Private');

# %%
#8f
college['Elite'] = pd.cut(college['Top10perc'], [0,50,100],labels=['No', 'Yes'])

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot('Outstate', by='Elite');

# %%
#8g
from matplotlib.pyplot import subplots
fig, ax = subplots(2,2)
college.hist('Enroll', ax=ax[0,0])
college.hist('PhD', ax=ax[0,1])
college.hist('Grad.Rate', ax=ax[1,0])
college.hist('Top10perc', ax=ax[1,1]);

# %% [markdown]
# #8h)
# #I found that private schools have a higher skew for graduation rate than public schools. I also found that there is no association between percentage of faculty w/PhD and graduation rate, but there is a slight association between expenditure and graduation rate due to the outliers.

# %%
college.boxplot('Grad.Rate', by='Private');

# %%
pd.plotting.scatter_matrix(college[['PhD','Grad.Rate','Expend']]);

# %%
#10a
boston=pd.read_csv('Boston.csv')

# %%
boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat  medv
# ...

# %%
#10b
boston.shape
#There are 506 rows and 14 columns.
#Each row represents one neighborhood (in Boston) and each column represents a characterstic of that house.
# Out:
# (506, 14)

# %%
#10c
pd.plotting.scatter_matrix(boston[['age','crim',"lstat",'nox','dis','medv']]);
#Here I found that older omes tend to have slightly higher rates of low socioeconomic status.
#I also found that there is only a slight change in crime when the low socioeconomic status rate rises from 10% to 30%.

# %%
#10d
#Yes, there are some predictors that are (somewhat) associated with the crime rate,
#such as age, lstat, and nox, which have a positive relationship with crime rate.
#We also have dis and medv have a negative relationship

# %%
#10e
#There appears to be quite a few suburbs of Boston that have outlyingly higher crime rates (~40%).
#There are quite a lot of suburbs that have outlyingly higher tax rates (~$700).
#There is no suburb that has a higher pupil-teacher ratio.
from matplotlib.pyplot import subplots
fig, ax = subplots(2,2)
boston.hist('crim', ax=ax[0,0])
boston.hist('tax', ax=ax[0,1])
boston.hist('ptratio', ax=ax[1,0]);

# %%
#10f
#There are 35 suburbs that bound the Charles River.
boston['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
#10g
#The median pupil-teacher ratio is 19.05.
boston[['ptratio']].describe()
# Out:
#           ptratio
# count  506.000000
# mean    18.455534
# std      2.164946
# min     12.600000
# 25%     17.400000
# 50%     19.050000
# 75%     20.200000
# max     22.000000

# %%
#10h
#Suburb 398 and 405 have the lowest median value of owner occupied homes.
#These suburbs have higher crime rates (both are outliers), higher tax rates, higher lower status percentage,
#and higher nitrogen oxide concentration. (All are compared to the median)
boston.sort_values(by='medv')
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 398         399  38.35180   0.0  18.10     0  0.693  5.453  100.0  1.4896
# 405         406  67.92080   0.0  18.10     0  0.693  5.683  100.0  1.4254
# 400         401  25.04610   0.0  18.10     0  0.693  5.987  100.0  1.5888
# 399         400   9.91655   0.0  18.10     0  0.693  5.852   77.8  1.5004
# 414         415  45.74610   0.0  18.10     0  0.693  4.519  100.0  1.6582
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 166         167   2.01019   0.0  19.58     0  0.605  7.929   96.2  2.0459
# 195         196   0.01381  80.0   0.46     0  0.422  7.875   32.0  5.6484
# 283         284   0.01501  90.0   1.21     1  0.401  7.923   24.8  5.8850
# 225         226   0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944
# 186         187   0.05602   0.0   2.46     0  0.488  7.831   53.6  3.1992
#
#      rad  tax  ptratio  lstat  medv
# 398   24  666     20.2  30.59   5.0
# ...

# %%
#10i
#There are 64 suburbs that average more than seven rooms per dwelling
#and 14 that average more than eight rooms per dwelling,
print(boston[boston['rm']>=7].shape[0])
boston[boston['rm']>=8].shape[0]
# Out:
# 64
# 13

# %%
boston[boston['rm']>=8]
#Most of the suburbs that average more than eight rooms per dwelling
#seem to have older houses and a higher median value of owner-occupied homes.
# Out:
#      Unnamed: 0     crim    zn  indus  chas     nox     rm   age     dis  rad  \
# 97           98  0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2
# 163         164  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5
# 204         205  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4
# 224         225  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8
# 225         226  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8
# 226         227  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8
# 232         233  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8
# 233         234  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8
# 253         254  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7
# 257         258  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5
# 262         263  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5
# ...

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...
